# %% [markdown]
# # Тест [1] - EDA + visualisation
#
# Первый тест из двух, которые запланированны на этот курс. В этом тесте нужно будет самостоятельно выполнить первые два шага для решения задачи ML. Первый, довольно комплексный, скачать датасет и провести разведочный анализ данных. Второй - нарисовать несколько графиков и поработать с гипотезами.
#
# Датасет можно найти на kaggle.com или в репозитории UCI. Ссылка на [kaggle](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data), ссылка на [UCI](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29)
#
# После выполнения заданий нужно заполнить форму, в которой отметить свои ответы, а свою тетрадку прислать мне в виде .pynb файла или ссылки (GitHub например) в личку ВКонтакте или в DM в Discord'e

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('breast-cancer-wisconsin-data/data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# Найдите id всех обьектов, у которых radius_mean больше 27

# %%
data[data['radius_mean'] > 27]
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 180     873592         M        27.22         21.87           182.1
# 212    8810703         M        28.11         18.47           188.5
# 461  911296202         M        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 180     2250.0           0.1094            0.1914          0.2871
# 212     2499.0           0.1142            0.1516          0.3201
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 180               0.1878  ...          32.85            220.8      3216.0
# 212               0.1595  ...          18.47            188.5      2499.0
# 461               0.1689  ...          31.37            251.2      4254.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 180            0.1472             0.4034           0.5340
# ...

# %% [markdown]
# С помощью регулярных выражений (regex) и функции pd.DataFrame.filter() из исходного датасета выберите только те признаки в которых содержится radius, area, texture, id и diagnosis и скопируйте их в новый датасет, с другим названием

# %%
new_data = data.filter(regex='radius|area|texture|id|diagnosis').copy()

# %% [markdown]
# Гипотеза 1 - Действительно ли среднее значение параметра radius_mean для обьектов со злокачественной опухолью будет больше, чем для обьектов с доброкачественной ?

# %%
new_data[new_data['diagnosis'] == 'M']['radius_mean'].mean(), \
new_data[new_data['diagnosis'] == 'B']['radius_mean'].mean()
# Out:
# (17.462830188679245, 12.146523809523808)

# %% [markdown]
# Гипотеза 2 - Верно ли утверждение что, минимальное значение параметра radius_worst, для обьектов со злокачественной опухолью будет больше чем максимальное значение того же параметра для обьектов с доброкачественной опухолью ?

# %%
new_data[new_data['diagnosis'] == 'M']['radius_worst'].min(), \
new_data[new_data['diagnosis'] == 'B']['radius_worst'].max()
# Out:
# (12.84, 19.82)

# %% [markdown]
# Сколько обьектов имеют значение permiter_mean больше чем квантиль в 0.95 этого параметра ?

# %%
data[data['perimeter_mean'] > data['perimeter_mean'].quantile(.95)].shape[0]
# Out:
# 29

# %% [markdown]
# Теперь перейдем к построению графиков и диаграмм. Постройте график на котором будут отражены парные зависимости для всех параметров, чьи имена заканчиваются на mean, и видна разница между обьектами с diagnosis == M и diagnosis == B. Подсказка: стоит воспользоваться регулярными выражениями

# %%
fin_data = data.filter(regex='mean$|diagnosis').copy()
sns.pairplot(fin_data, hue='diagnosis')

# %% [markdown]
# Необходимо построить 2 графика, которые наглядно проилюстрируют гипотезы 1 и 2. Так что бы человек сразу мог понять, подтверждаются они или нет.

# %%
fig, ax = plt.subplots(1, 2, figsize=(8, 3))
new_data.boxplot(column='radius_mean', by='diagnosis', ax=ax[0])
new_data.boxplot(column='radius_worst', by='diagnosis', ax=ax[1])
plt.show()

# %% [markdown]
# Необходимо построить график на котором будут отражены средние значения по каждому параметру для обьектов с доброкачественной и недоброкачественной опоухолями, примерно такого вида <img src='pic.png'>
